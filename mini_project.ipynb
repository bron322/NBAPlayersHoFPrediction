# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %%
rookiedata = pd.read_csv('rookie_data.csv')
rookiedata.head()
# Out:
#    index           Name  Hall of Fame Class  Year Drafted    GP   MIN   PTS  \
# 0      0    Jeff Taylor                 NaN        1982.0  44.0  17.6   3.6
# 1      1  Charles Smith                 NaN        1988.0  71.0  30.4  16.3
# 2      2     Mark Davis                 NaN        1988.0  33.0   7.8   3.8
# 3      3  Charles Smith                 NaN        1989.0  60.0   8.7   2.9
# 4      4  Michael Smith                 NaN        1989.0  65.0   9.5   5.0
#
#    FGM   FGA   FG%  ...  FTA   FT% OREB  DREB  REB  AST  STL  BLK  TOV   EFF
# 0  1.5   3.6  40.0  ...  1.0  65.2  0.6   1.2  1.8  2.5  0.9  0.3  1.4   5.2
# 1  6.1  12.4  49.5  ...  5.5  72.5  2.4   4.1  6.5  1.5  1.0  1.3  2.1  16.7
# 2  1.5   3.1  48.0  ...  1.0  82.4  0.5   0.6  1.1  0.4  0.4  0.1  0.4   3.8
# 3  1.0   2.2  44.4  ...  1.3  69.7  0.2   0.9  1.2  1.7  0.6  0.1  0.6   4.1
# 4  2.1   4.4  47.6  ...  1.0  82.8  0.6   0.9  1.5  1.2  0.1  0.0  0.8   4.6
#
# [5 rows x 24 columns]

# %%
rookiedata['Hall of Fame Class'] = rookiedata['Hall of Fame Class'].apply(lambda x:0 if pd.isna(x) else 1)
rookiedata.head(40)
# Out:
#     index               Name  Hall of Fame Class  Year Drafted    GP   MIN  \
# 0       0        Jeff Taylor                   0        1982.0  44.0  17.6
# 1       1      Charles Smith                   0        1988.0  71.0  30.4
# 2       2         Mark Davis                   0        1988.0  33.0   7.8
# 3       3      Charles Smith                   0        1989.0  60.0   8.7
# 4       4      Michael Smith                   0        1989.0  65.0   9.5
# 5       5          Dee Brown                   0        1990.0  82.0  23.7
# 6       6      Michael Smith                   0        1994.0  82.0  21.2
# 7       7         Mark Davis                   0        1995.0  57.0  10.0
# 8       8      Charles Smith                   0        1997.0  34.0   8.6
# 9       9          Dee Brown                   0        2006.0  49.0   9.2
# 10     10        Jeff Taylor                   0        2012.0  77.0  19.6
# 11     11       Andrew Toney                   0        1980.0  75.0  23.6
# 12     12       Bill Hanzlik                   0        1980.0  74.0  17.0
# 13     13      Bill Laimbeer                   0        1980.0  81.0  30.4
# 14     14         Billy Reid                   0        1980.0  59.0  10.1
# 15     15       Butch Carter                   0        1980.0  54.0  12.4
# 16     16     Calvin Garrett                   0        1980.0  70.0  23.4
# 17     17    Cedrick Hordges                   0        1980.0  68.0  23.5
# 18     18    Charles Whitney                   0        1980.0  47.0  16.6
# 19     19      Craig Shelton                   0        1980.0  55.0  10.7
# 20     20   Darrell Griffith                   0        1980.0  81.0  35.4
# 21     21        Darwin Cook                   0        1980.0  81.0  24.4
# 22     22     Dewayne Scales                   0        1980.0  44.0  11.0
# 23     23        Don Collins                   0        1980.0  81.0  22.8
# 24     24       Earl Cureton                   0        1980.0  52.0  10.2
# 25     25        Edgar Jones                   0        1980.0  60.0  15.8
# 26     26    James Donaldson                   0        1980.0  68.0  14.4
# 27     27       James Wilkes                   0        1980.0  48.0  11.3
# 28     28       Jeff Wilkins                   0        1980.0  56.0  18.9
# 29     29     Jerry Sichting                   0        1980.0  47.0   9.6
# 30     30  Joe Barry Carroll                   0        1980.0  82.0  35.6
# 31     31         John Duren                   0        1980.0  40.0  11.5
# 32     32       Johnny Moore                   0        1980.0  82.0  19.2
# 33     33      Kelvin Ransey                   0        1980.0  80.0  30.4
# 34     34       Kevin McHale                   1        1980.0  82.0  20.1
# 35     35    Kiki Vandeweghe                   0        1980.0  51.0  27.0
# 36     36          Kyle Macy                   0        1980.0  82.0  17.9
# 37     37         Larry Drew                   0        1980.0  76.0  20.8
# 38     38        Larry Smith                   0        1980.0  82.0  31.4
# 39     39      Lorenzo Romar                   0        1980.0  53.0  13.7
#
#      PTS  FGM   FGA   FG%  ...  FTA   FT% OREB  DREB   REB  AST  STL  BLK  \
# 0    3.6  1.5   3.6  40.0  ...  1.0  65.2  0.6   1.2   1.8  2.5  0.9  0.3
# 1   16.3  6.1  12.4  49.5  ...  5.5  72.5  2.4   4.1   6.5  1.5  1.0  1.3
# 2    3.8  1.5   3.1  48.0  ...  1.0  82.4  0.5   0.6   1.1  0.4  0.4  0.1
# 3    2.9  1.0   2.2  44.4  ...  1.3  69.7  0.2   0.9   1.2  1.7  0.6  0.1
# 4    5.0  2.1   4.4  47.6  ...  1.0  82.8  0.6   0.9   1.5  1.2  0.1  0.0
# 5    8.7  3.5   7.5  46.4  ...  1.9  87.3  0.5   1.7   2.2  4.2  1.0  0.2
# 6    6.9  2.7   5.0  54.2  ...  3.2  48.5  2.1   3.8   5.9  0.8  0.7  0.6
# 7    3.3  1.0   2.6  36.9  ...  2.0  63.8  1.0   1.2   2.2  0.8  0.7  0.4
# 8    3.5  1.4   3.7  39.2  ...  0.3  54.5  0.4   0.4   0.8  0.6  0.3  0.2
# 9    1.9  0.7   2.0  32.7  ...  0.8  64.9  0.2   0.7   0.8  1.7  0.5  0.1
# 10   6.1  2.2   5.2  43.1  ...  1.3  72.8  0.7   1.3   1.9  0.8  0.6  0.2
# 11  12.9  5.3  10.7  49.5  ...  3.0  71.2  0.4   1.5   1.9  3.6  0.8  0.1
# 12   5.4  1.9   3.9  47.8  ...  2.0  79.3  0.9   1.2   2.1  1.5  0.8  0.3
# 13   9.8  4.2   8.3  50.3  ...  1.9  76.5  3.3   5.3   8.6  2.7  0.7  1.0
# 14   3.2  1.4   3.1  45.4  ...  0.7  56.4  0.5   0.6   1.0  1.2  0.6  0.1
# 15   5.6  2.1   4.6  46.2  ...  1.8  73.7  0.6   0.6   1.2  1.0  0.4  0.0
# 16   6.1  2.7   5.9  45.3  ...  0.9  80.6  1.2   2.6   3.8  1.9  0.7  0.1
# 17   8.4  3.3   7.1  46.0  ...  2.7  69.9  1.8   5.0   6.7  1.5  0.5  0.3
# 18   7.4  3.2   6.5  48.7  ...  1.4  76.9  0.6   1.6   2.3  1.4  1.0  0.1
# 19   4.3  1.8   4.0  45.7  ...  1.1  60.3  1.1   1.4   2.5  0.5  0.3  0.1
# 20  20.6  8.8  19.1  46.4  ...  4.0  71.6  1.0   2.6   3.6  2.4  1.3  0.5
# 21  11.2  4.7  10.1  46.8  ...  2.2  73.3  1.2   1.7   2.9  3.7  1.7  0.4
# 22   4.9  2.1   5.1  41.8  ...  0.9  66.7  1.1   1.9   3.0  0.2  0.3  0.1
# 23  11.5  4.4  10.0  44.4  ...  3.4  77.6  1.6   1.7   3.3  2.3  1.3  0.3
# 24   4.2  1.8   3.9  45.4  ...  1.2  51.6  1.0   2.0   3.0  0.5  0.4  0.4
# 25   8.7  3.2   6.0  52.9  ...  3.6  67.0  1.5   2.9   4.4  0.7  0.6  1.4
# 26   5.3  1.9   3.5  54.2  ...  2.5  59.4  1.6   3.0   4.5  0.6  0.1  1.1
# 27   4.1  1.8   3.8  46.2  ...  0.9  69.0  0.8   1.3   2.0  0.6  0.5  0.3
# 28   4.7  2.1   4.6  45.0  ...  0.7  67.5  1.1   3.8   4.9  0.7  0.6  0.8
# 29   2.0  0.7   2.0  35.8  ...  0.7  78.1  0.2   0.7   0.9  1.5  0.5  0.0
# 30  18.9  7.5  15.3  49.1  ...  5.4  71.6  3.3   5.9   9.3  1.4  0.6  1.5
# 31   1.8  0.8   2.5  32.7  ...  0.2  55.6  0.2   0.7   0.9  1.4  0.5  0.1
# 32   7.4  3.0   6.3  47.9  ...  2.1  61.0  0.7   1.7   2.4  4.5  1.5  0.3
# 33  15.2  6.6  14.5  45.2  ...  2.7  74.9  0.5   1.9   2.4  6.9  1.1  0.1
# 34  10.0  4.3   8.1  53.3  ...  1.9  67.9  1.9   2.5   4.4  0.7  0.3  1.8
# 35  11.5  4.5  10.5  42.6  ...  3.1  81.8  1.7   3.6   5.3  1.8  0.6  0.5
# 36   8.1  3.3   6.5  51.1  ...  1.5  89.9  0.5   1.1   1.6  2.0  0.9  0.1
# 37   6.6  2.6   6.4  40.7  ...  1.8  79.7  0.3   1.3   1.6  3.3  1.2  0.1
# 38   9.6  3.7   7.2  51.2  ...  3.7  58.8  5.3   6.8  12.1  1.1  0.8  0.8
# 39   4.1  1.6   4.0  41.2  ...  1.2  68.3  0.2   0.9   1.1  2.6  0.5  0.1
#
#     TOV   EFF
# 0   1.4   5.2
# 1   2.1  16.7
# 2   0.4   3.8
# 3   0.6   4.1
# 4   0.8   4.6
# 5   1.7  10.4
# 6   1.3   9.8
# 7   1.2   3.8
# 8   0.8   2.3
# 9   0.6   2.8
# 10  0.6   5.8
# 11  2.9  10.2
# 12  1.1   6.4
# 13  1.6  16.5
# 14  1.3   2.8
# 15  0.9   4.3
# 16  1.3   7.9
# 17  1.8  11.0
# 18  1.0   7.6
# 19  1.1   4.0
# 20  2.9  14.2
# 21  2.2  11.8
# 22  0.7   4.5
# 23  2.1  10.3
# 24  0.6   5.2
# 25  1.7  10.1
# 26  1.0   8.0
# 27  0.7   4.5
# 28  1.1   7.8
# 29  0.6   2.9
# 30  3.0  19.4
# 31  0.9   1.8
# 32  1.9  10.0
# 33  2.9  14.3
# 34  1.3  11.4
# 35  1.7  11.4
# 36  1.2   8.2
# 37  2.2   6.4
# 38  1.8  17.6
# 39  1.0   4.6
#
# [40 rows x 24 columns]

# %% [markdown]
# I cleaned the data by making the Hall of Fame Class to have either 0 and 1 data. 0 means not in Hall of Fame whereas 1 means in Hall of Fame.

# %%
#removing outliers that has the lowest gameplays
Q1 = rookiedata['GP'].quantile(0.25)
Q3 = rookiedata['GP'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
rookiedata = rookiedata[rookiedata['GP'] >= lower_bound]

# %%
corr_matrix = rookiedata.corr()
corr_with_eff = corr_matrix.loc['EFF']
corr_with_eff_sorted = corr_with_eff.sort_values(ascending=False)
print(corr_with_eff_sorted)
# Out:
# EFF                   1.000000
# PTS                   0.917685
# FGM                   0.916489
# MIN                   0.912166
# FGA                   0.865477
# DREB                  0.856875
# FTA                   0.853805
# FTM                   0.848361
# REB                   0.846272
# TOV                   0.802314
# OREB                  0.735390
# STL                   0.679017
# GP                    0.564192
# BLK                   0.559781
# AST                   0.529017
# FG%                   0.410704
# Hall of Fame Class    0.286684
# 3P Made               0.182441
# 3PA                   0.179117
# FT%                   0.154037
# index                -0.068305
# Year Drafted         -0.073093
# Name: EFF, dtype: float64

# %%
train_data, test_data = train_test_split(rookiedata, test_size=0.2, random_state=0)

# %%
def regression(data,target_var, predictor):
    train_x = train_data[[predictor]].values
    train_y = train_data[[target_var]].values
    test_x = test_data[[predictor]].values
    test_y = test_data[[target_var]].values
    reg = LinearRegression().fit(train_x,train_y)
    intercept = reg.intercept_
    coefficients = reg.coef_
    
    # Formula for the Regression line
    regline_x = train_x
    regline_y = reg.intercept_ + reg.coef_ * train_x

    # Plot the Linear Regression line
    f, axes = plt.subplots(1, 1, figsize=(16, 8))
    plt.scatter(train_x, train_y)
    plt.plot(regline_x, regline_y, 'r-', linewidth = 3)
    plt.show()
    
    # Predict SalePrice values corresponding to GrLivArea
    y_test_pred = reg.predict(test_x)
    
    # Plot the Predictions on a Scatterplot
    f = plt.figure(figsize=(16, 8))
    plt.scatter(test_x, test_y, color = "green")
    plt.scatter(test_x, y_test_pred, color = "red")
    plt.show()
    
    # Explained Variance in simply the "Score"
    print("Explained Variance (R^2) \t:", reg.score(train_x, train_y))
    
    # Compute MSE on the test set
    print("Mean Squared Error (MSE) \t:", mean_squared_error(test_y, y_test_pred))
    print("Intercept:" , intercept)
    print("Coefficients: " , coefficients)
    return intercept, coefficients

# %%
# predict Efficiency using PTS
intercept, coefficients = regression(rookiedata, "EFF", "PTS")
# Out:
# Explained Variance (R^2) 	: 0.8456605917585719
# Mean Squared Error (MSE) 	: 3.0148090493054513
# Intercept: [0.7467568]
# Coefficients:  [[0.99041791]]

# %%
# predict Efficiency using PTS
intercept, coefficients = regression(rookiedata, "EFF", "FGM")
# Out:
# Explained Variance (R^2) 	: 0.8434506647068412
# Mean Squared Error (MSE) 	: 3.0489693112825766
# Intercept: [0.7572144]
# Coefficients:  [[2.5635032]]

# %%
# predict Efficiency using MIN
intercept, coefficients = regression(rookiedata, "EFF", "MIN")
# Out:
# Explained Variance (R^2) 	: 0.829749948322163
# Mean Squared Error (MSE) 	: 2.6810078588554918
# Intercept: [-1.67380358]
# Coefficients:  [[0.51624411]]

# %%
# Extract Response and Predictors
y = pd.DataFrame(rookiedata["EFF"])
X = pd.DataFrame(rookiedata[["PTS", "FGM", "MIN"]])

# Import train_test_split from sklearn
from sklearn.model_selection import train_test_split

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# Check the sample sizes
print("Train Set :", y_train.shape, X_train.shape)
print("Test Set  :", y_test.shape, X_test.shape)
# Out:
# Train Set : (1229, 1) (1229, 3)
# Test Set  : (308, 1) (308, 3)

# %%
# Summary Statistics for Response
y_train.describe()
# Out:
#                EFF
# count  1229.000000
# mean      7.421806
# std       4.632365
# min       0.200000
# 25%       3.900000
# 50%       6.300000
# 75%       9.800000
# max      30.600000

# %%
# Summary Statistics for Predictors
X_train.describe()
# Out:
#                PTS          FGM          MIN
# count  1229.000000  1229.000000  1229.000000
# mean      6.722213     2.591538    17.599675
# std       4.334047     1.668215     8.220652
# min       0.700000     0.300000     3.100000
# 25%       3.600000     1.400000    11.100000
# 50%       5.400000     2.100000    15.900000
# 75%       8.700000     3.300000    22.800000
# max      28.200000    10.200000    40.900000

# %%
# Draw the distribution of Response
f, axes = plt.subplots(1, 3, figsize=(24, 6))
sb.boxplot(data = y_train, orient = "h", ax = axes[0])
sb.histplot(data = y_train, ax = axes[1])
sb.violinplot(data = y_train, orient = "h", ax = axes[2])
# Out:
# <AxesSubplot:>

# %%
# Draw the distributions of all Predictors
f, axes = plt.subplots(3, 3, figsize=(18, 12))

count = 0
for var in X_train:
    sb.boxplot(data = X_train[var], orient = "h", ax = axes[count,0])
    sb.histplot(data = X_train[var], ax = axes[count,1])
    sb.violinplot(data = X_train[var], orient = "h", ax = axes[count,2])
    count += 1

# %%
# Correlation between Response and the Predictors
trainDF = pd.concat([y_train, X_train], axis = 1).reindex(y_train.index)

f = plt.figure(figsize=(12, 8))
sb.heatmap(trainDF.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f")
# Out:
# <AxesSubplot:>

# %%
# Relationship between Response and the Predictors
sb.pairplot(data = trainDF)

# %% [markdown]
# ## We hypothesise a linear regression model:
# EFF = a1 x PTS + a2 x FGM + a3 x MIN + b
#       where a1 is PTS coefficient, a2 is FGM coefficient, a3 is MIN coefficient and b is the intercept of regression.

# %%
# Import LinearRegression model from Scikit-Learn
from sklearn.linear_model import LinearRegression


# Linear Regression using Train Data
linreg = LinearRegression()         # create the linear regression object
linreg.fit(X_train, y_train)        # train the linear regression model

# Coefficients of the Linear Regression line
print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()

# Print the Coefficients against Predictors
pd.DataFrame(list(zip(X_train.columns, linreg.coef_[0])), columns = ["Predictors", "Coefficients"])
# Out:
# Intercept of Regression 	: b =  [-0.7067954]
# Coefficients of Regression 	: a =  [[0.16571612 1.02110469 0.24820864]]
#   Predictors  Coefficients
# 0        PTS      0.165716
# 1        FGM      1.021105
# 2        MIN      0.248209

# %%
# Import mean_squared_error from sklearn
from sklearn.metrics import mean_squared_error

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print()
# Out:
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.884389924485807
# Mean Squared Error (MSE) 	: 2.478835757734284
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.8618559158827263
# Mean Squared Error (MSE) 	: 2.458268312120647

# %% [markdown]
# ## As we can see, when we were doing uni-variate linear regression, the R^2 value was just 0.845, 0.843 , 0.829 for PTS, FGM, MIN as predictors respectively. When we use multi-variate linear regression, we have R^2 value to be 0.884 which is higher than when we were doing uni-variate linear regression.
